# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    predecessors = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')
        predecessors[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

def get_shortest_path(predecessors, start_node, end_node):
    path = []
    current = end_node
    while current is not None:
        path.insert(0, current)
        current = predecessors[current]
    if path[0] == start_node:
        return path
    else:
        return []

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 6},
    'D': {'B': 10, 'C': 3, 'F': 7},
    'E': {'C': 6, 'F': 1},
    'F': {'D': 7, 'E': 1}
}

# Test with source node 'A'
start_node_A = 'A'
distances_A, predecessors_A = dijkstra(graph, start_node_A)

print(f"Shortest paths from source node '{start_node_A}':")
for node in graph:
    path = get_shortest_path(predecessors_A, start_node_A, node)
    total_distance = distances_A[node]
    print(f"  To {node}: Distance = {total_distance}, Path = {' -> '.join(path)}")

print("\n" + "-"*30 + "\n")

# Test with a different source node 'C'
start_node_C = 'C'
distances_C, predecessors_C = dijkstra(graph, start_node_C)

print(f"Shortest paths from source node '{start_node_C}':")
for node in graph:
    path = get_shortest_path(predecessors_C, start_node_C, node)
    total_distance = distances_C[node]
    print(f"  To {node}: Distance = {total_distance}, Path = {' -> '.join(path)}")
# Out:
# Shortest paths from source node 'A':
#   To A: Distance = 0, Path = A
#   To B: Distance = 4, Path = A -> B
#   To C: Distance = 2, Path = A -> C
#   To D: Distance = 5, Path = A -> C -> D
#   To E: Distance = 8, Path = A -> C -> E
#   To F: Distance = 9, Path = A -> C -> E -> F
#
# ------------------------------
#
# Shortest paths from source node 'C':
#   To A: Distance = 2, Path = C -> A
#   To B: Distance = 5, Path = C -> B
#   To C: Distance = 0, Path = C
#   To D: Distance = 3, Path = C -> D
#   To E: Distance = 6, Path = C -> E
#   To F: Distance = 7, Path = C -> E -> F

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %% [markdown]
# ### Define Your Custom Graph
# You can define your own graph here by modifying the `user_graph` dictionary below. Each key represents a node, and its value is another dictionary where keys are neighboring nodes and values are the weights of the edges.

# %%
# Define your custom graph here
user_graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

print("Your custom graph:")
for node, neighbors in user_graph.items():
    print(f"  {node}: {neighbors}")
# Out:
# Your custom graph:
#   A: {'B': 1, 'C': 4}
#   B: {'A': 1, 'C': 2, 'D': 5}
#   C: {'A': 4, 'B': 2, 'D': 1}
#   D: {'B': 5, 'C': 1}

# %%
# Test the Dijkstra algorithm with your custom graph

# You can change the start_node for your custom graph test
start_node_user = 'A'

if start_node_user not in user_graph:
    print(f"Error: Start node '{start_node_user}' not found in your custom graph.")
elif not user_graph:
    print("Error: Your custom graph is empty.")
else:
    distances_user, predecessors_user = dijkstra(user_graph, start_node_user)

    print(f"\nShortest paths from source node '{start_node_user}' for your custom graph:")
    for node in user_graph:
        path = get_shortest_path(predecessors_user, start_node_user, node)
        total_distance = distances_user[node]
        print(f"  To {node}: Distance = {total_distance}, Path = {' -> '.join(path)}")
# Out:
# Shortest paths from source node 'A' for your custom graph:
#   To A: Distance = 0, Path = A
#   To B: Distance = 1, Path = A -> B
#   To C: Distance = 3, Path = A -> B -> C
#   To D: Distance = 4, Path = A -> B -> C -> D
